# %%
l = [10, 20, 30, 40, 50]
for v in l:
    print(v)
# Out:
# 10
# 20
# 30
# 40
# 50

# %% [markdown]
# # iterators
#
#         - an iterator is an object which contain countable value
#
#         - any object which want to be in iterator must follow these protocol
#
#             - iter method is called on initialization to get next of __next__ method
#
#             - next should return the next value of iterator

# %%
l = [10, 20, 30, 40, 50]
print(dir(l))

# befor initialization only __iter__ method is there
# Out:
# ['__add__', '__class__', '__contains__', '__delattr__', '__delitem__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__iadd__', '__imul__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__mul__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__rmul__', '__setattr__', '__setitem__', '__sizeof__', '__str__', '__subclasshook__', 'append', 'clear', 'copy', 'count', 'extend', 'index', 'insert', 'pop', 'remove', 'reverse', 'sort']

# %%
l = [10, 20, 30, 40, 50]

i = iter(l)

# when iter is initialized we can see __next__
print(dir(i))


# next will return only one value at a time
print('\n')
print(next(i))
print(next(i))
print(next(i))

# after 3 iteration
print(list(i))

# when new iter is defined in same list
j = iter(l)
print(list(j))
# Out:
# ['__class__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__length_hint__', '__lt__', '__ne__', '__new__', '__next__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__setstate__', '__sizeof__', '__str__', '__subclasshook__']
#
#
# 10
# 20
# 30
# [40, 50]
# [10, 20, 30, 40, 50]

# %%
# what if when you append iterator
l = [10, 20, 30, 40, 50]
i = iter(l)
i.append(60)

# will return : AttributeError: 'list_iterator' object has no attribute 'append'
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-21ccf111d455> in <module>
#       2 l = [10, 20, 30, 40, 50]
#       3 i = iter(l)
# ----> 4 i.append(60)
#       5
#       6 # will return : AttributeError: 'list_iterator' object has no attribute 'append'
#
# AttributeError: 'list_iterator' object has no attribute 'append'

# %%
my_iterator = iter([1, 2, 3, 4, 5, 6])

print(next(my_iterator))
print(next(my_iterator))

# %%
my_iterator = iter('krsign')

print(next(my_iterator))
print(next(my_iterator))

# %%
# all iterators are iterable
i = iter([1, 2, 3, 4, 5, 6])

my_iter = [ x for x in i]
print(my_iter)

# now we can't iterate
i_iter = [ x for x in i]
print(i_iter)

# %%
print(dir(range))

# range is not an iterator

# %%
iter(range(4))

# %%
# but we cannot call next 
next(range(4))

# %%
import itertools
import operator

# %% [markdown]
# # accumulate()
#     - itertools.accumulate(iterable, func)

# %%
data = [1,2,3,4,5]
result = itertools.accumulate(data, operator.mul)
for i in result:
    print(i)

# %% [markdown]
# # loop:
#
#         1  *  2  = 2
#
#         2  *  3  = 6
#
#         6  *  4  = 24
#
#         24 *  5  = 120

# %%
# max 

data = [5, 2, 6, 4, 5, 9, 1]
result = itertools.accumulate(data, max)

for i in result:
    print(i)

# %% [markdown]
# # loop:
#
#     5
#
#     max(5, 2)
#     5
#
#     max(5, 6)
#     6
#
#     max(6, 4)
#     6
#
#     max(6, 5)
#     6
#
#     max(6, 9)
#     9
#
#     max(9, 1)
#     9

# %% [markdown]
# # combinations()
#
#         - itertools.combination(iterable, n members)

# %%
color = ['brown', 'black', 'white']

unique = itertools.combinations(color, 2)

for i in unique:
    print(i)

# %% [markdown]
# # combinations_with_replacement()
#
#          - itertools.combinations_with_replacement(iterable, n members)

# %%
color = ['brown', 'black', 'white']

result = itertools.combinations_with_replacement(color, 2)

for i in result:
    print(i)

# %% [markdown]
# # count()
#         - itertools.count(start = 0, step = 1)

# %%
for i in itertools.count(10, 3):
    print(i)
    if i > 20:
        break

# %% [markdown]
# # cycle()
#         - this function cycles through an iterators endlessly

# %%
colors = ['brown', 'black', 'white']
for color in itertools.cycle(colors):
    print(color)

# this will go endlessly

# %% [markdown]
# # chain()
#         - itertools.chain(*iterables)
#
#         - returns as one iterables

# %%
color_balls = ['red', 'black', 'white', ]
num_balls = [1, 2, 3, 4]

result = itertools.chain(color_balls, num_balls)
for i in result:
    print(i)
# Out:
# red
# black
# white
# 1
# 2
# 3
# 4

# %% [markdown]
# # compress()
#         - itertools.compress(data, selectors)
#         - filters one iterables with another

# %%
colors = ['red', 'white', 'blue']
selections = [True, True, False]

result = itertools.compress(colors, selections)
for i in result:
    print(i)
# Out:
# red
# white

# %% [markdown]
# # islice()
#         - itertools.islice(iterable, start, stop, step)
#
#         -

# %% [markdown]
# # permutations()
#     - itertools.permutations(iterable, r=None)

# %% [markdown]
# # product()

# %% [markdown]
# # repeat()
#     - itertools.repeat(object[, times])
#     - This function will repeat an object over and over again. Unless, there is a times argument.
